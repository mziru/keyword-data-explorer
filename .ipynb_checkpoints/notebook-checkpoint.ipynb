# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import math

# TMDB developer keys are available for free from TMDB: https://developers.themoviedb.org/3/getting-started/introduction

def tmdb_keyword_query(kw_list, api_key):

    """
    Uses the TMDB Web API to generate list of movie ids based on keyword search.
    :param kw_list: list of keyword strings
    :param api_key: API key string
    :return: list of unique ids
    """

    # return keyword ids and store them as a pipe-delimited string

    kw_id_list=[]

    for kw in kw_list:
        url = 'https://api.themoviedb.org/3/search/keyword?api_key={key}&query={query}'\
                 .format(key=api_key, query=kw)

        session = Session()

        try:
          response = session.get(url)
          kw_ids = json.loads(response.text)

        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)

        df = pd.json_normalize(kw_ids['results'])
        kw_ids = list(df['id'])
        kw_ids = [str(kw_id) for kw_id in kw_ids]
        for kw_id in kw_ids:
            kw_id_list.append(kw_id)

    piped_ids = '|'.join(kw_id_list)

    # return first page of results, check total page count for all results, and set page range maximum

    url = '''https://api.themoviedb.org/3/discover/movie?with_keywords={ids}
            &page={page_num}
            &api_key={key}&'''.format(ids=piped_ids, page_num=1, key=api_key)

    session = Session()

    try:
      response = session.get(url)
      kw_data = json.loads(response.text)
      page_max = kw_data['total_pages']+1

    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    # loop through page range to generate list of movie ids

    id_list = []
    for p in range(1,page_max):
        url = '''https://api.themoviedb.org/3/discover/movie?with_keywords={ids}
            &page={page_num}
            &api_key={key}&'''.format(ids=piped_ids, page_num=p, key=api_key)

        session = Session()

        try:
          response = session.get(url)
          kw_data = json.loads(response.text)
        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)

        kw_df = pd.json_normalize(kw_data['results'])
        id_list.append(kw_df['id'])

    id_list = [i_list for i in id_list for i_list in i]

    # estimate time to build dataset

    time_estimate = math.ceil(len(id_list) * 0.002)

    print('It will take about {} minute(s) to build this dataset based on {} movies. Proceed?'.format(time_estimate, f'{len(id_list):,d}'))
    return id_list


def build_dataset(id_list, api_key):
    """
    Builds dataset using TMDB web API
    :param id_list: list of TMDB unique ids
    :param api_key:
    :return: Pandas Dataframe
    """

    data_dict = {}
    for id in id_list:
        url = 'https://api.themoviedb.org/3/movie/{movie_id}?api_key={key}'.format(movie_id=id, key=api_key)

        session = Session()

        try:
          response = session.get(url)
          data = json.loads(response.text)

        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)

        data_dict[id] = data

    data_df = pd.DataFrame.from_dict(data_dict, orient='index')
    return data_df

ids = tmdb_keyword_query(['robot'], '1a639c8e33a30017bb883bf46d80f183')
# Out:
# It will take about 1 minute(s) to build this dataset based on 493 movies. Proceed?

# %%
df_orig = build_dataset(ids, '1a639c8e33a30017bb883bf46d80f183')

# %%
df = df_orig.dropna(subset=['release_date'])
df['release_date'] = pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 493 entries, 522402 to 34700
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  493 non-null    bool
#  1   backdrop_path          344 non-null    object
#  2   belongs_to_collection  98 non-null     object
#  3   budget                 493 non-null    int64
#  4   genres                 493 non-null    object
#  5   homepage               468 non-null    object
#  6   id                     493 non-null    int64
#  7   imdb_id                455 non-null    object
#  8   original_language      493 non-null    object
#  9   original_title         493 non-null    object
#  10  overview               493 non-null    object
#  11  popularity             493 non-null    float64
#  12  poster_path            447 non-null    object
#  13  production_companies   493 non-null    object
#  14  production_countries   493 non-null    object
#  15  release_date           485 non-null    datetime64[ns]
#  16  revenue                493 non-null    int64
#  17  runtime                489 non-null    float64
#  18  spoken_languages       493 non-null    object
#  19  status                 493 non-null    object
#  20  tagline                493 non-null    object
#  21  title                  493 non-null    object
#  22  video                  493 non-null    bool
#  23  vote_average           493 non-null    float64
#  24  vote_count             493 non-null    int64
#  25  year                   485 non-null    float64
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(4), object(15)
# memory usage: 97.3+ KB

# %%
df = df[['genres','title', 'popularity', 'year', 'poster_path', 'overview', 'tagline']].sort_values('year')
df
# Out:
#                                                    genres  \
# 108253  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...
# 147546  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 19      [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 161662  [{'id': 10749, 'name': 'Romance'}, {'id': 16, ...
# 181164  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# ...                                                   ...
# 914076                  [{'id': 16, 'name': 'Animation'}]
# 843794           [{'id': 878, 'name': 'Science Fiction'}]
# 633947  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 546222  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 522834  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
#
#                            title  popularity    year  \
# 108253        The Master Mystery       0.734  1918.0
# 147546           Cartoon Factory       0.711  1924.0
# 19                    Metropolis      17.482  1927.0
# 161662                 The Robot       0.600  1932.0
# 181164      The Vanishing Shadow       1.121  1934.0
# ...                          ...         ...     ...
# 914076                      HUBO       0.600     NaN
# 843794                   Jung Yi       0.600     NaN
# 633947                Only Human       0.600     NaN
# 546222  Extrinsic: The Beginning       0.600     NaN
# 522834                 EXTRiNSIC       0.600     NaN
#
#                              poster_path  \
# 108253  /4iVxiG9h3GndLadPlfZi5k1tCnt.jpg
# 147546                              None
# 19      /hUK9rewffKGqtXynH5SW3v9hzcu.jpg
# 161662  /7KHhcNiTz02Loux9db5T5xEgOoS.jpg
# 181164  /aljqB1O1wg9CetTSprOXIHKsak8.jpg
# ...                                  ...
# 914076  /6gH3vVY4k5M8ueu3Gh9qPfSFwUA.jpg
# 843794                              None
# 633947  /cnlZOrG5aqdMzKsPymSszlv3AjM.jpg
# 546222  /zsNpVg8O8Cbl25MYn46kqjlc8tV.jpg
# 522834  /4moQnrQvnNBu19Cs4ZBeASaDp2A.jpg
#
#                                                  overview  \
# 108253  In this action-packed serial, government agent...
# 147546  Koko the Clown discovers a machine that can ma...
# 19      In a futuristic city sharply divided between t...
# 161662  Bimbo is a mechanic whose girlfriend (not Bett...
# 181164  A 12-episode serial in which a son avenges the...
# ...                                                   ...
# 914076  HUBO (KHR-3) is a walking humanoid robot with ...
# 843794
# 633947  Ordinary citizens now augment themselves with ...
# 546222  In the year 2053, Artificially Intelligent bei...
# 522834  In the year 2057, new technology has allowed t...
#
#                                                   tagline
# 108253
# 147546
# 19      There can be no understanding between the hand...
# 161662
# 181164
# ...                                                   ...
# 914076
# 843794
# 633947     The Year is 2034... Lines and Laws are Blurred
# 546222                                 What would you do?
# 522834         It escaped. It's learning. It's out there.
#
# [493 rows x 7 columns]

# %%
import ast

def fix_list(value_list):
    string = str(value_list)
    dicts_list = ast.literal_eval(string)
    string_list = []
    for d in dicts_list:
        string_list.append(d['name'])
    new_string = ','.join(string_list)
    return new_string

df['genres'] = df['genres'].apply(fix_list)

# %%
df
# Out:
#                                   genres                     title  \
# 108253                    Action,Mystery        The Master Mystery
# 147546                  Animation,Comedy           Cartoon Factory
# 19                 Drama,Science Fiction                Metropolis
# 161662          Romance,Animation,Comedy                 The Robot
# 181164            Science Fiction,Action      The Vanishing Shadow
# ...                                  ...                       ...
# 914076                         Animation                      HUBO
# 843794                   Science Fiction                   Jung Yi
# 633947  Science Fiction,Mystery,Thriller                Only Human
# 546222          Science Fiction,Thriller  Extrinsic: The Beginning
# 522834          Thriller,Science Fiction                 EXTRiNSIC
#
#         popularity    year                       poster_path  \
# 108253       0.734  1918.0  /4iVxiG9h3GndLadPlfZi5k1tCnt.jpg
# 147546       0.711  1924.0                              None
# 19          17.482  1927.0  /hUK9rewffKGqtXynH5SW3v9hzcu.jpg
# 161662       0.600  1932.0  /7KHhcNiTz02Loux9db5T5xEgOoS.jpg
# 181164       1.121  1934.0  /aljqB1O1wg9CetTSprOXIHKsak8.jpg
# ...            ...     ...                               ...
# 914076       0.600     NaN  /6gH3vVY4k5M8ueu3Gh9qPfSFwUA.jpg
# 843794       0.600     NaN                              None
# 633947       0.600     NaN  /cnlZOrG5aqdMzKsPymSszlv3AjM.jpg
# 546222       0.600     NaN  /zsNpVg8O8Cbl25MYn46kqjlc8tV.jpg
# 522834       0.600     NaN  /4moQnrQvnNBu19Cs4ZBeASaDp2A.jpg
#
#                                                  overview  \
# 108253  In this action-packed serial, government agent...
# 147546  Koko the Clown discovers a machine that can ma...
# 19      In a futuristic city sharply divided between t...
# 161662  Bimbo is a mechanic whose girlfriend (not Bett...
# 181164  A 12-episode serial in which a son avenges the...
# ...                                                   ...
# 914076  HUBO (KHR-3) is a walking humanoid robot with ...
# 843794
# 633947  Ordinary citizens now augment themselves with ...
# 546222  In the year 2053, Artificially Intelligent bei...
# 522834  In the year 2057, new technology has allowed t...
#
#                                                   tagline
# 108253
# 147546
# 19      There can be no understanding between the hand...
# 161662
# 181164
# ...                                                   ...
# 914076
# 843794
# 633947     The Year is 2034... Lines and Laws are Blurred
# 546222                                 What would you do?
# 522834         It escaped. It's learning. It's out there.
#
# [493 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

overall_freq = df['year'].value_counts().sort_index()
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(overall_freq.index, pd.Series(overall_freq.values).rolling(3).mean(), figure=fig)
plt.show()

# %%
top_genres = df['genres'].value_counts().head(8).index
unique_genres = set(
                ",".join(top_genres)
                   .strip()
                   .split(",")
                )
if '' in unique_genres:
    unique_genres.remove('')

unique_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Science Fiction'}

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)

genre_percent_dict = {}
for genre in unique_genres:
    genre_df = df[df['genres'].str.contains(genre)]
    genre_freq = genre_df['year'].value_counts().sort_index()
    genre_percent = (genre_freq/overall_freq*100).fillna(0)
    genre_percent_dict[genre] = genre_percent
    ax.plot(overall_freq.index, genre_percent.rolling(7).mean(), label = genre)
ax.legend()
plt.show()

# %%
import numpy as np
import seaborn as sns

genre_list = []
percent_list = []
for genre in genre_percent_dict:
    genre_list.append(genre)
    percent_list.append(genre_percent_dict[genre])

corrs = np.corrcoef(percent_list)
sns.heatmap(corrs, linewidths=.5, xticklabels=genre_list, yticklabels=genre_list)
plt.xticks(rotation=45)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

overview_words = ''
stopwords = set(STOPWORDS)
text_cols = [
            # 'title',
            # 'tagline',
            'overview'
            ]
# iterate through the data
for col in text_cols:
    for val in df[col]:

        # typecaste each val to string
        val = str(val)

        # split the value
        tokens = val.split()

        # Converts each token into lowercase
        for i in range(len(tokens)):
            tokens[i] = tokens[i].lower()

        overview_words += " ".join(tokens)+" "

    wordcloud = WordCloud(width = 1000, height = 600,
                    background_color ='white',
                    stopwords = stopwords,
                    min_font_size = 10).generate(overview_words)

    # plot the WordCloud image
    plt.figure(figsize = (12, 10), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    print(col, 'word cloud')
    plt.show()
# Out:
# overview word cloud

# %%
poster_df = df[df['poster_path'].notna()].sort_values('year')
poster_df = poster_df[['year', 'title', 'poster_path']].dropna()
poster_df['poster_path'] = poster_df['poster_path'].apply(lambda x: 'https://image.tmdb.org/t/p/w200{}'.format(x))

poster_df['year'] = poster_df['year'] // 10 * 10
poster_df.value_counts('year', sort=False)
# Out:
# year
# 1910.0      1
# 1920.0      1
# 1930.0      6
# 1940.0      5
# 1950.0     18
# 1960.0     15
# 1970.0     35
# 1980.0     55
# 1990.0     43
# 2000.0     66
# 2010.0    170
# 2020.0     25
# dtype: int64

# %%
decades = poster_df['year'].unique()
source_dict = {}
for decade in decades:
    decade_df = poster_df[poster_df['year'] == decade]
    source_dict[decade] = list(decade_df['poster_path'].values)

# %%
source_dict
# Out:
# {1910.0: ['https://image.tmdb.org/t/p/w200/4iVxiG9h3GndLadPlfZi5k1tCnt.jpg'],
#  1920.0: ['https://image.tmdb.org/t/p/w200/hUK9rewffKGqtXynH5SW3v9hzcu.jpg'],
#  1930.0: ['https://image.tmdb.org/t/p/w200/7KHhcNiTz02Loux9db5T5xEgOoS.jpg',
#   'https://image.tmdb.org/t/p/w200/aljqB1O1wg9CetTSprOXIHKsak8.jpg',
#   'https://image.tmdb.org/t/p/w200/qSngO3JT8ICqvOvgBg4zXbucDF.jpg',
#   'https://image.tmdb.org/t/p/w200/4KEQbYuQUY1NMjMAbuJr1JQ02Pg.jpg',
#   'https://image.tmdb.org/t/p/w200/dRuCC4yAgIGRjsTz8evhNsCXM3d.jpg',
#   'https://image.tmdb.org/t/p/w200/gsjPEN30Z7WJFMQIgAYUzbxCjvx.jpg'],
#  1940.0: ['https://image.tmdb.org/t/p/w200/xSPCXeiwCHC7I0OzolebQLHrSxI.jpg',
#   'https://image.tmdb.org/t/p/w200/oph26KBekK3COTCEiaWlAcwmIFd.jpg',
#   'https://image.tmdb.org/t/p/w200/9jRqxSpDaeyKHdIAdL0H1Y1EwZy.jpg',
#   'https://image.tmdb.org/t/p/w200/6jVk91dKlY9DXmBUhKFKNN2hTXd.jpg',
#   'https://image.tmdb.org/t/p/w200/pxDekfQeobu7zONfRGzA5vy0RxL.jpg',
#   'https://image.tmdb.org/t/p/w200/oPeCo68dPgqPUdE2uO9KGswxMdT.jpg',
#   'https://image.tmdb.org/t/p/w200/m4LFXv42TqQ6rYwDAznG3s8ENd2.jpg',
#   'https://image.tmdb.org/t/p/w200/hhsBEr9HdEOsluuYB1oY8Y8XoBA.jpg',
#   'https://image.tmdb.org/t/p/w200/urC3np6cAiyxzuamNMtmZRl2Dr0.jpg',
#   'https://image.tmdb.org/t/p/w200/uOVGbT6TR8qiZiruX66yBRXq9Nv.jpg',
#   'https://image.tmdb.org/t/p/w200/gRGmCgrOPz7oClOCqG1JhGowDPH.jpg',
#   'https://image.tmdb.org/t/p/w200/b3jWxwWRFqvNDJTvBcmKJVHnzKK.jpg',
#   'https://image.tmdb.org/t/p/w200/ghD2HJyAk6EYVHrzBhddNDJ73Go.jpg',
#   'https://image.tmdb.org/t/p/w200/xAEWxHZUuWS4s0DsNbYlfhBpNLd.jpg',
#   'https://image.tmdb.org/t/p/w200/js04LRJ439cxdbDguien9TZQDS2.jpg',
#   'https://image.tmdb.org/t/p/w200/xDwrNByqI1SXUA4opc0mJNFW2xL.jpg',
#   'https://image.tmdb.org/t/p/w200/kkpeYDMS0LPLPtQveJGvkLMk4V8.jpg',
#   'https://image.tmdb.org/t/p/w200/fhfGvNbuSWJbRcS5HYBP1FBy3ZY.jpg',
#   'https://image.tmdb.org/t/p/w200/w2SGnd9Ca3BTXEK8mjVT1bJY6Zx.jpg',
#   'https://image.tmdb.org/t/p/w200/izGX7npHEopDQvngYcxMJEfcFbj.jpg',
#   'https://image.tmdb.org/t/p/w200/1sTnNspjOhwFtsKc1VpHdmwMPy8.jpg',
#   'https://image.tmdb.org/t/p/w200/aFf6bbHBHdONWgToHpgZmxKZeSw.jpg'],
#  2020.0: ['https://image.tmdb.org/t/p/w200/fuq9jXbc9cLgsaWXC19oMJKTjBJ.jpg',
#   'https://image.tmdb.org/t/p/w200/1f3qspv64L5FXrRy0MF8X92ieuw.jpg',
#   'https://image.tmdb.org/t/p/w200/bwPHxNgvJ7cCbvstrh84zCEQdi1.jpg',
#   'https://image.tmdb.org/t/p/w200/mVOX82R4y2Wq4bAZPVAfxvttG0i.jpg',
#   'https://image.tmdb.org/t/p/w200/eDnHgozW8vfOaLHzfpHluf1GZCW.jpg',
#   'https://image.tmdb.org/t/p/w200/fsPZdpocYYbvDS2YEE1Xohqo1ni.jpg',
#   'https://image.tmdb.org/t/p/w200/xLRySOZovbFlrsKje9DbXfKec7e.jpg',
#   'https://image.tmdb.org/t/p/w200/6YSA26GDyTLK1BLol2rTG0SqXEk.jpg',
#   'https://image.tmdb.org/t/p/w200/cSKXdkm38HIMsZZNYJDIOtfOV9B.jpg',
#   'https://image.tmdb.org/t/p/w200/r3z7W86G9dbRMhZ2SsfhLHO3lTJ.jpg',
#   'https://image.tmdb.org/t/p/w200/tMmh5gdCv07hMx4Jdl7TPIvfoGg.jpg',
#   'https://image.tmdb.org/t/p/w200/hHtJhevKKC3ZNPslcojfLMecYjo.jpg',
#   'https://image.tmdb.org/t/p/w200/cwHDHnJagDAaysnEZZUppxpzHqg.jpg',
#   'https://image.tmdb.org/t/p/w200/rO3nV9d1wzHEWsC7xgwxotjZQpM.jpg',
#   'https://image.tmdb.org/t/p/w200/ajfwZWgL27wP35V3V5d8wAo7AUc.jpg',
#   'https://image.tmdb.org/t/p/w200/zffYFbD9jtGxz1jnpNCGDol1Nad.jpg',
#   'https://image.tmdb.org/t/p/w200/t1pHIeZZGmr8TWMyn7r1TGoMnMo.jpg',
#   'https://image.tmdb.org/t/p/w200/vA1BwFOWLHZYhwCUVyQ67GESpAY.jpg',
#   'https://image.tmdb.org/t/p/w200/311p9CmE8AirYnOyYK4vOC8rDiO.jpg',
#   'https://image.tmdb.org/t/p/w200/yiuTDzmfkH9bvNE4cICOXvIO6vu.jpg',
#   'https://image.tmdb.org/t/p/w200/62e6YMUv3S8Pgz3F6pzaJIJzDhn.jpg',
#   'https://image.tmdb.org/t/p/w200/pgqgaUx1cJb5oZQQ5v0tNARCeBp.jpg',
#   'https://image.tmdb.org/t/p/w200/iQofL5fGS1VgjnzDWbNocLzEjLu.jpg',
#   'https://image.tmdb.org/t/p/w200/6XYLiMxHAaCsoyrVo38LBWMw2p8.jpg',
#   'https://image.tmdb.org/t/p/w200/jKuDyqx7jrjiR9cDzB5pxzhJAdv.jpg']}

# %%
import ipyplot

images = []
labels = []
for i in source_dict:
    for url in source_dict[i]:
        images.append(url)
        label = str(i)[:4]+'s'
        labels.append(label)

ipyplot.plot_class_tabs(images=images, labels=labels, max_imgs_per_tab=200, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XN3EVkkhcxY86sfLM4GQ6m {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XN3EVkkhcxY86sfLM4GQ6m {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XN3EVkkhcxY86sfLM4GQ6m {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XN3EVkkhcxY86sfLM4GQ6m:checked ~ #ipyplot-html-viewer-textarea-XN3EVkkhcxY86sfLM4GQ6m {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XN3EVkkhcxY86sfLM4GQ6m:checked + #ipyplot-html-viewer-label-XN3EVkkhcxY86sfLM4GQ6m:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-XN3EVkkhcxY86sfLM4GQ6m">
#         <label id="ipyplot-html-viewer-label-XN3EVkkhcxY86sfLM4GQ6m" for="ipyplot-html-viewer-toggle-XN3EVkkhcxY86sfLM4GQ6m">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-XN3EVkkhcxY86sfLM4GQ6m" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-eygsDBJLGmHmXXtJRTZid8 {
#                 display: none;
#             }
#             input.ipyplot-tab-eygsDBJLGmHmXXtJRTZid8 + label.ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-eygsDBJLGmHmXXtJRTZid8:checked + label.ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-eygsDBJLGmHmXXtJRTZid8 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-eygsDBJLGmHmXXtJRTZid8 ~ .tab {
#                 display: none
#             }
#     #tabPCCF7dFqxM8KEWVT5QbtYJ:checked ~ .tab.contentPCCF7dFqxM8KEWVT5QbtYJ,#tabHinnpt7ouq6sSFMZgMLYR7:checked ~ .tab.contentHinnpt7ouq6sSFMZgMLYR7,#tabJZwHerHpZy6DhW3MaTBrrW:checked ~ .tab.contentJZwHerHpZy6DhW3MaTBrrW,#tabMnDMv5MVYPRCcPNm45f8LU:checked ~ .tab.contentMnDMv5MVYPRCcPNm45f8LU,#tabDhLppdKTvYEx8KeLGXyP6w:checked ~ .tab.contentDhLppdK
m,#tabJV7s8JjgAvBaVn7LWmj4DT:checked ~ .tab.contentJV7s8JjgAvBaVn7LWmj4DT,#tab4SsJjhiZEmT5p4Lne8Sq9Z:checked ~ .tab.content4SsJjhiZEmT5p4Lne8Sq9Z,#tabALoKqtESSyoZddWAiTZrK5:checked ~ .tab.contentALoKqtESSyoZddWAiTZrK5,#tabZScbP3RizB8Skaxb5md6ai:checked ~ .tab.contentZScbP3RizB8Skaxb5md6ai,#tabnPPd6hhZ2qWi9dTgs3XzWR:checked ~ .tab.contentnPPd6hhZ2qWi9dTgs3XzWR,#tabDtqhjXEuXjiJsVC3wKbNfp:checked ~ .tab.contentDtqhjXEuXjiJsVC3wKbNfp{ display: block; }</style><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabPCCF7dFqxM8KEWVT5QbtYJ" checked /><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabPCCF7dFqxM8KEWVT5QbtYJ">1910s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabHinnpt7ouq6sSFMZgMLYR7"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabHinnpt7ouq6sSFMZgMLYR7">1920s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabJZwHerHpZy6DhW3MaTBrrW"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabJZwHerHpZy6DhW3MaTBrrW">1930s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabMnDMv5MVYPRCcPNm45f8LU"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabMnDMv5MVYPRCcPNm45f8LU">1940s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabDhLppdKTvYEx8KeLGXyP6w"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabDhLppdKTvYEx8KeLGXyP6w">1950s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabGuFXm888MetHbbS9Bs4pfm"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabGuFXm888MetHbbS9Bs4pfm">1960s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabJV7s8JjgAvBaVn7LWmj4DT"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabJV7s8JjgAvBaVn7LWmj4DT">1970s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tab4SsJjhiZEmT5p4Lne8Sq9Z"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tab4SsJjhiZEmT5p4Lne8Sq9Z">1980s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabALoKqtESSyoZddWAiTZrK5"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabALoKqtESSyoZddWAiTZrK5">1990s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabZScbP3RizB8Skaxb5md6ai"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabZScbP3RizB8Skaxb5md6ai">2000s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabnPPd6hhZ2qWi9dTgs3XzWR"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabnPPd6hhZ2qWi9dTgs3XzWR">2010s</label><input class="ipyplot-tab-eygsDBJLGmHmXXtJRTZid8" type="radio" name="tabs-eygsDBJLGmHmXXtJRTZid8" id="tabDtqhjXEuXjiJsVC3wKbNfp"/><label class="ipyplot-tab-label-eygsDBJLGmHmXXtJRTZid8" for="tabDtqhjXEuXjiJsVC3wKbNfp">2020s</label><div class="tab contentPCCF7dFqxM8KEWVT5QbtYJ">
#         <style>
#         #ipyplot-imgs-container-div-XCkNiATvHvAYNYKze2U8jN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-XCkNiATvHvAYNYKze2U8jN {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XCkNiATvHvAYNYKze2U8jN">
#     <div class="ipyplot-placeholder-div-XCkNiATvHvAYNYKze2U8jN">
#         <div id="ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN-komjAiCYpg5vJiauMBfbtt" class="ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://image.tmdb.org/t/p/w200/4iVxiG9h3GndLadPlfZi5k1tCnt.jpg</h4><img src="https://image.tmdb.org/t/p/w200/4iVxiG9h3GndLadPlfZi5k1tCnt.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XCkNiATvHvAYNYKze2U8jN-komjAiCYpg5vJiauMBfbtt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentHinnpt7ouq6sSFMZgMLYR7">
#         <style>
#         #ipyplot-imgs-container-div-adnqQeXsURu7mkpgu7QHCS {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-adnqQeXsURu7mkpgu7QHCS {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
